# %%
GOOGLE_COLAB = False
if GOOGLE_COLAB:
    from google.colab import drive

    drive.mount("/content/gdrive")
    # !pip install kornia
    # %cd gdrive/MyDrive/Projet_Colorisation

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from src.image_colorization import ECCVImage, LoriaImageColorization
from PIL import Image


image = torch.tensor(np.array(Image.open("src/images/lion_fabien.jpg")))  # [:, :, 0]

# %%
loria_colorizer = LoriaImageColorization(image)
loria_colorizer.plot_eccv()
loria_colorizer.optimize(0.02, 5)
loria_colorizer.plot_result()
# Out:
# /home/gaetano/Documents/Loria/Colorisation/src/image_colorization.py:144: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.proba_distrib = torch.tensor(
# torch.Size([1, 313, 64, 64])
